# %%
# !pip3 install poetry
# !poetry install --with yolo  # installed boxmot + yolo dependencies
# %cd Course_project/504 CV/boxmot
import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 2.2.2 (CPU)

# %%
# Activate the Poetry shell

# !pwd
# !ls
# Out:
# /Users/apple/Course_project/504CV/boxmot
# CITATION.cff          gp.ipynb              runs
# Dockerfile            gp.ipynb_副本         test.avi
# LICENSE               osnet_x0_25_msmt17.pt tests
# MANIFEST.in           out.avi               tracking
# MOT17-13-FRCNN.txt    out.mp4               vedio
# MOT17-13.txt          output.mp4            yolov10s.pt
# README.md             palace.mp4            yolov8n.pt
# assets                poetry.lock           yolov8s.pt
# boxmot                pyproject.toml
# examples              renovate.json

# %%
# extract 3 seconds worth of video frames of it
# !ffmpeg -y -ss 00:00:00 -i test.avi -t 00:00:10 -vf fps=30 out.mp4
# Out:
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with clang version 18.1.8
# ...

# %%
# !poetry run python tracking/track.py --yolo-model yolov8s.pt --reid-model osnet_x0_25_msmt17.pt --source out.mp4 --save --conf 0.2 --tracking-method bytetrack --save-txt
# Out:
# WARNING ⚠️ Python>=3.10 is required, but Python==3.9.18 is currently installed
#
# video 1/1 (frame 1/300) /Users/apple/Course_project/504CV/boxmot/out.mp4: 384x640 9 persons, 1 car, 1 motorcycle, 137.0ms
# video 1/1 (frame 2/300) /Users/apple/Course_project/504CV/boxmot/out.mp4: 384x640 9 persons, 1 car, 1 motorcycle, 105.9ms
# video 1/1 (frame 3/300) /Users/apple/Course_project/504CV/boxmot/out.mp4: 384x640 9 persons, 1 car, 1 motorcycle, 106.1ms
# video 1/1 (frame 4/300) /Users/apple/Course_project/504CV/boxmot/out.mp4: 384x640 9 persons, 1 car, 1 motorcycle, 106.8ms
# video 1/1 (frame 5/300) /Users/apple/Course_project/504CV/boxmot/out.mp4: 384x640 9 persons, 1 car, 1 motorcycle, 109.2ms
# video 1/1 (frame 6/300) /Users/apple/Course_project/504CV/boxmot/out.mp4: 384x640 9 persons, 1 car, 1 motorcycle, 106.7ms
# video 1/1 (frame 7/300) /Users/apple/Course_project/504CV/boxmot/out.mp4: 384x640 9 persons, 1 car, 1 motorcycle, 121.2ms
# ...

# %%
# !ffmpeg -y -i /Users/apple/Course_project/504CV/boxmot/runs/track/exp29/out.mp4 -vf fps=30 -vcodec libx264 output.mp4
# Out:
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with clang version 18.1.8
# ...

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('output.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

# %%
HTML("""
<video controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %%
# !poetry run python tracking/val.py --yolo-model yolov8s.pt --reid-model osnet_x0_25_msmt17.pt --tracking-method deepocsort --benchmark MOT17-mini --source tracking/val_utils/data/MOT17-mini/train --conf 0.5
# Out:
# WARNING ⚠️ Python>=3.10 is required, but Python==3.9.18 is currently installed
# 2024-11-13 17:48:33.280 | INFO     | tracking.utils:download_mot_eval_tools:118 - Evaluation repo already downloaded or an error occurred: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://github.com/JonathonLuiten/TrackEval /Users/apple/Course_project/504CV/boxmot/tracking/val_utils
#   stderr: 'fatal: destination path '/Users/apple/Course_project/504CV/boxmot/tracking/val_utils' already exists and is not an empty directory.
# '
# 2024-11-13 17:48:34.675 | WARNING  | tracking.utils:download_mot_dataset:200 - MOT17-mini is not downloadable from https://motchallenge.net/data/MOT17-mini.zip
# 2024-11-13 17:48:34.676 | WARNING  | tracking.utils:unzip_mot_dataset:237 - No zip file. Skipping unzipping
# Detections and Embeddings /Users/apple/Course_project/504CV/boxmot/runs/dets_n_embs/yolov8s/dets/MOT17-04-FRCNN.txt already exists. Overwrite? [y/N]:
# ...

# %%
# !poetry run python tracking/val.py --yolo-model yolov8s.pt --reid-model osnet_x0_25_msmt17.pt --tracking-method bytetrack --benchmark MOT17 --source tracking/val_utils/data/MOT17/train --conf 0.2
# Out:
# WARNING ⚠️ Python>=3.10 is required, but Python==3.9.18 is currently installed
# 2024-11-13 17:39:42.906 | INFO     | tracking.utils:download_mot_eval_tools:118 - Evaluation repo already downloaded or an error occurred: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://github.com/JonathonLuiten/TrackEval /Users/apple/Course_project/504CV/boxmot/tracking/val_utils
#   stderr: 'fatal: destination path '/Users/apple/Course_project/504CV/boxmot/tracking/val_utils' already exists and is not an empty directory.
# '
# 2024-11-13 17:39:43.859 | INFO     | tracking.utils:download_mot_dataset:170 - MOT17.zip is already fully downloaded.
# 2024-11-13 17:40:08.423 | INFO     | tracking.utils:unzip_mot_dataset:247 - MOT17.zip unzipped successfully.
# Moved tracking/val_utils/data/MOT17/train/MOT17-02-FRCNN to tracking/val_utils/data/MOT17/train/MOT17-02
# Removed tracking/val_utils/data/MOT17/train/MOT17-02-SDP
# ...

# %%
# !poetry run python tracking/val.py --yolo-model yolov8s.pt --reid-model osnet_x0_25_msmt17.pt --tracking-method deepocsort --benchmark MOT17 --source tracking/val_utils/data/MOT17/train --conf 0.2
# Out:
# WARNING ⚠️ Python>=3.10 is required, but Python==3.9.18 is currently installed
# 2024-11-13 17:49:47.938 | INFO     | tracking.utils:download_mot_eval_tools:118 - Evaluation repo already downloaded or an error occurred: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://github.com/JonathonLuiten/TrackEval /Users/apple/Course_project/504CV/boxmot/tracking/val_utils
#   stderr: 'fatal: destination path '/Users/apple/Course_project/504CV/boxmot/tracking/val_utils' already exists and is not an empty directory.
# '
# 2024-11-13 17:49:49.228 | INFO     | tracking.utils:download_mot_dataset:170 - MOT17.zip is already fully downloaded.
# 2024-11-13 17:49:49.230 | INFO     | tracking.utils:unzip_mot_dataset:253 - MOT17 folder already exists.
# Sequence MOT17-05 is already cleaned. Skipping.
# Sequence MOT17-11 is already cleaned. Skipping.
# Sequence MOT17-02 is already cleaned. Skipping.
# Sequence MOT17-10 is already cleaned. Skipping.
# ...

# %%
# !poetry run python tracking/val.py --yolo-model yolov8s.pt --reid-model osnet_x0_25_msmt17.pt --tracking-method botsort --benchmark MOT17 --source tracking/val_utils/data/MOT17/train --conf 0.2
# Out:
# WARNING ⚠️ Python>=3.10 is required, but Python==3.9.18 is currently installed
# 2024-11-14 13:42:17.657 | INFO     | tracking.utils:download_mot_eval_tools:118 - Evaluation repo already downloaded or an error occurred: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://github.com/JonathonLuiten/TrackEval /Users/apple/Course_project/504CV/boxmot/tracking/val_utils
#   stderr: 'fatal: destination path '/Users/apple/Course_project/504CV/boxmot/tracking/val_utils' already exists and is not an empty directory.
# '
# 2024-11-14 13:42:20.262 | INFO     | tracking.utils:download_mot_dataset:170 - MOT17.zip is already fully downloaded.
# 2024-11-14 13:42:20.263 | INFO     | tracking.utils:unzip_mot_dataset:253 - MOT17 folder already exists.
# Sequence MOT17-09 is already cleaned. Skipping.
# Sequence MOT17-04 is already cleaned. Skipping.
# Sequence MOT17-10 is already cleaned. Skipping.
# Sequence MOT17-11 is already cleaned. Skipping.
# ...

# %%
# !poetry run python tracking/val.py --yolo-model yolov8s.pt --reid-model osnet_x0_25_msmt17.pt --tracking-method ocsort --benchmark MOT17 --source tracking/val_utils/data/MOT17/train --conf 0.2
# Out:
# WARNING ⚠️ Python>=3.10 is required, but Python==3.9.18 is currently installed
# 2024-11-14 13:46:23.252 | INFO     | tracking.utils:download_mot_eval_tools:118 - Evaluation repo already downloaded or an error occurred: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://github.com/JonathonLuiten/TrackEval /Users/apple/Course_project/504CV/boxmot/tracking/val_utils
#   stderr: 'fatal: destination path '/Users/apple/Course_project/504CV/boxmot/tracking/val_utils' already exists and is not an empty directory.
# '
# 2024-11-14 13:46:24.937 | INFO     | tracking.utils:download_mot_dataset:170 - MOT17.zip is already fully downloaded.
# 2024-11-14 13:46:24.938 | INFO     | tracking.utils:unzip_mot_dataset:253 - MOT17 folder already exists.
# Sequence MOT17-04 is already cleaned. Skipping.
# Sequence MOT17-09 is already cleaned. Skipping.
# Sequence MOT17-05 is already cleaned. Skipping.
# Sequence MOT17-13 is already cleaned. Skipping.
# ...

# %%
# !poetry run python tracking/val.py --yolo-model yolov8s.pt --reid-model osnet_x0_25_msmt17.pt --tracking-method strongsort --benchmark MOT17 --source tracking/val_utils/data/MOT17/train --conf 0.2
# Out:
# WARNING ⚠️ Python>=3.10 is required, but Python==3.9.18 is currently installed
# 2024-11-14 13:48:47.408 | INFO     | tracking.utils:download_mot_eval_tools:118 - Evaluation repo already downloaded or an error occurred: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://github.com/JonathonLuiten/TrackEval /Users/apple/Course_project/504CV/boxmot/tracking/val_utils
#   stderr: 'fatal: destination path '/Users/apple/Course_project/504CV/boxmot/tracking/val_utils' already exists and is not an empty directory.
# '
# 2024-11-14 13:48:48.753 | INFO     | tracking.utils:download_mot_dataset:170 - MOT17.zip is already fully downloaded.
# 2024-11-14 13:48:48.754 | INFO     | tracking.utils:unzip_mot_dataset:253 - MOT17 folder already exists.
# Sequence MOT17-13 is already cleaned. Skipping.
# Sequence MOT17-09 is already cleaned. Skipping.
# Sequence MOT17-05 is already cleaned. Skipping.
# Sequence MOT17-02 is already cleaned. Skipping.
# ...

# %%
# !poetry run python tracking/val.py --yolo-model yolov8s.pt --reid-model osnet_x0_25_msmt17.pt --tracking-method imprassoc --benchmark MOT17 --source tracking/val_utils/data/MOT17/train --conf 0.2
# Out:
# WARNING ⚠️ Python>=3.10 is required, but Python==3.9.18 is currently installed
# 2024-11-14 14:15:37.630 | INFO     | tracking.utils:download_mot_eval_tools:118 - Evaluation repo already downloaded or an error occurred: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://github.com/JonathonLuiten/TrackEval /Users/apple/Course_project/504CV/boxmot/tracking/val_utils
#   stderr: 'fatal: destination path '/Users/apple/Course_project/504CV/boxmot/tracking/val_utils' already exists and is not an empty directory.
# '
# 2024-11-14 14:15:39.165 | INFO     | tracking.utils:download_mot_dataset:170 - MOT17.zip is already fully downloaded.
# 2024-11-14 14:15:39.166 | INFO     | tracking.utils:unzip_mot_dataset:253 - MOT17 folder already exists.
# Sequence MOT17-10 is already cleaned. Skipping.
# Sequence MOT17-11 is already cleaned. Skipping.
# Sequence MOT17-13 is already cleaned. Skipping.
# Sequence MOT17-04 is already cleaned. Skipping.
# ...
